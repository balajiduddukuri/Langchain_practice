# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiduddukuri/Langchain_practice/blob/Ultimate-Content-Repurposer/LangChain_Mar07_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain_openai langchain_community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.7/502.7 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
from google.colab import userdata
import os

# Retrieve your key securely:
api_key = userdata.get("api_key")

# Set it as an environment variable:
os.environ['OPENAI_API_KEY'] = api_key

print("OPENAI API key is loaded successfully")
# Out:
# OPENAI API key is loaded successfully

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

llm = ChatOpenAI(model = "gpt-4o-mini", temperature = 0.7)

# %%
from langchain_core.messages import HumanMessage

# Define a simple query string
query = 'Explain the concept of large language models in one sentence.'

# Invoke the llm object with the query wrapped in a HumanMessage object
response = llm.invoke([HumanMessage(content=query)])

# Print the content attribute of the response
print(response.content)
# Out:
# Large language models are advanced artificial intelligence systems that use vast amounts of text data to understand, generate, and manipulate human language, enabling them to perform a wide range of language-related tasks.

# %%
from langchain_core.prompts import PromptTemplate

# Create an instance of PromptTemplate
prompt_template = PromptTemplate(
    input_variables=["topic"],
    template="Generate a creative and unique short story idea about a {topic}. The idea should include a protagonist, a central conflict, and a surprising twist."
)

# Format the prompt with a sample topic
example_topic = "ancient civilizations"
formatted_prompt = prompt_template.format(topic=example_topic)

# Print the formatted prompt
print(formatted_prompt)
# Out:
# Generate a creative and unique short story idea about a ancient civilizations. The idea should include a protagonist, a central conflict, and a surprising twist.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model = "gpt-4o-mini")

reponse = llm.invoke(
    prompt.format(
        role = "AI Professor",
        style = "simple and friendly",
        topic = "Transformers",
        audience = "beginner students"
    )
)

print(response.content)
# Out:
# Sure! Transformers are a type of model used in natural language processing (NLP) and other machine learning tasks. Here's a simple breakdown of how they work:
#
# 1. **Purpose**: Transformers are designed to understand and generate human language, but they can also be used for tasks involving images, music, and more.
#
# 2. **Attention Mechanism**: The key innovation in transformers is the "attention mechanism." This allows the model to focus on different parts of the input data (like words in a sentence) when making predictions. For example, in the sentence "The cat sat on the mat," the model can pay more attention to "cat" when predicting what comes next after "The."
#
# 3. **Self-Attention**: In addition to paying attention to other words, each word looks at every other word in the sentence to gather context. This helps the model understand relationships between words, no matter their position in the sentence.
#
# ...

# %%
stream = llm.stream("Explain Transformers in simple terms")

for chunk in stream:
  print(chunk.content, end = "", flush = True)
# Out:
# Transformers are a type of model used in natural language processing (NLP) and other tasks involving sequences, such as translating languages or generating text. Here’s a simple breakdown of how they work:
#
# 1. **Structure**: A Transformer consists of an encoder and a decoder. The encoder processes the input (like a sentence), and the decoder generates the output (like a translated sentence).
#
# 2. **Attention Mechanism**: One of the key features of Transformers is the "attention mechanism." This allows the model to focus on different parts of the input when producing output. For example, when translating a sentence, the model can look back at specific words in the original sentence to help decide how to phrase things in the target language.
#
# 3. **Parallel Processing**: Unlike traditional models that process words one at a time, Transformers can look at all the words in a sentence at once. This helps them understand context better and speeds up the processing.
#
# ...

# %%
llm.invoke("Explain GAN")

llm.invoke("Explain Transformers")

llm.invoke("Explain Attention")
# Out:
# AIMessage(content='Attention is a cognitive process that enables individuals to selectively concentrate on specific information or stimuli while ignoring others. In the context of both human cognition and artificial intelligence, attention plays a critical role in filtering and prioritizing information.\n\n### Human Attention\nIn neuroscience and psychology, attention is the mental process of focusing on specific aspects of one’s environment or internal thoughts. There are different types of attention, such as:\n\n1. **Selective Attention**: The ability to focus on one particular stimulus while ignoring others. For instance, listening to a friend in a noisy room.\n   \n2. **Sustained Attention**: The capacity to maintain focus on a task or stimulus over a prolonged period. An example is studying for an exam.\n\n3. **Divided Attention**: The ability to process multiple streams of information or perform multiple tasks simultaneously, like driving while talking on the phone.\n\nAttentio
# ...

# %%
prompts = [
    "Explain GAN in simple terms",
    "Explain transformers in simple terms",
    "Explain Attention mechanism"
]


responses = llm.batch(prompts)

for r in responses:
  print(r.content)
# Out:
# A GAN, or Generative Adversarial Network, is a type of artificial intelligence that helps create new content, like images, music, or text. It consists of two main parts: a **Generator** and a **Discriminator**. Here’s how they work together:
#
# 1. **Generator**: This part creates new data. For example, if it’s making images, the generator produces pictures that aim to look realistic.
#
# 2. **Discriminator**: This part checks the data. It tries to tell the difference between real data (like actual photos) and the fake data created by the generator.
#
# They work as a team in a competitive way:
# - The generator wants to create data that can fool the discriminator.
# - The discriminator, on the other hand, gets better at spotting the fakes.
#
# ...

# %% [markdown]
# LCEL - LangChain Expression Language

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# %%
# define the model:
llm = ChatOpenAI(model = "gpt-4o-mini")

# Create a Prompt template:
prompt = PromptTemplate.from_template(
    "Explain {topic} in simple terms"
)

# %%
chain = prompt | llm

# %%
chain.invoke({"topic":"Transformers"})
# Out:
# AIMessage(content='Transformers are a type of model used in machine learning, particularly in natural language processing (NLP). You can think of them as a smart way for computers to understand and generate human language. Here’s a simple breakdown:\n\n1. **Language Understanding**: Transformers help computers read and understand text by looking at pieces of a sentence all at once, rather than one word at a time. This helps them grasp the context and relationships between words better.\n\n2. **Self-Attention Mechanism**: One of the key features of transformers is something called "self-attention." This allows the model to weigh the importance of each word in a sentence relative to the other words. For example, in the sentence "The cat sat on the mat," the model can recognize that "cat" and "sat" are closely related.\n\n3. **Layers**: Transformers are built in layers, with each layer refining the understanding of the input text a bit more. These layers work together to build a complex
# ...
