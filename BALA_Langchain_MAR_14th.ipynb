# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiduddukuri/Langchain_practice/blob/Ultimate-Content-Repurposer/BALA_Langchain_MAR_14th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install openai langchain chromadb faiss-cpu pypdf tiktoken docarray langchain_openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 2.7 MB/s eta 0:00:00

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.10
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
from google.colab import userdata
import os

os.environ['OPENAI_API_KEY'] = userdata.get("api_key")

print("OPENAI API key is loaded successfully")
# Out:
# OPENAI API key is loaded successfully

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model = "gpt-3.5-turbo") #gpt-4o-mini

query = "Explain 2 uses of human life in bullet points"

response = llm.invoke([HumanMessage(content = query)])

print(response.content)
# Out:
# - Human life can be used for the pursuit of knowledge and understanding, through activities such as scientific research, academic study, and personal exploration.
# - Human life can also be used for creativity and expression, through pursuits such as art, music, writing, and other forms of self-expression that enrich both the individual and society as a whole.

# %% [markdown]
# **MAR-14 Class

# %%
#MODEL IO

# %%
from pydantic import BaseModel
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# %%
class ModelInfo(BaseModel):
  name: str
  year: int
  inventor: str
  details: str

# %%
parser = PydanticOutputParser(pydantic_object = ModelInfo)

# %%
format_instructions = parser.get_format_instructions()

# %%
prompt = PromptTemplate.from_template(
    """
    Provide information about {topic}.

    {format_instructions}
    """
)

# %%
llm = ChatOpenAI(model = "gpt-4o-mini")

chain = prompt | llm | parser

result = chain.invoke({
    "topic": "Trnaformers",
    "format_instructions": parser.get_format_instructions()
})

print(result)
# Out:
# name='Transformers' year=2017 inventor='Vaswani et al.' details="Transformers are a type of neural network architecture introduced in the paper 'Attention is All You Need'. They are designed to handle sequential data for tasks such as translation and image processing, using mechanisms such as self-attention to improve performance on tasks involving long-range dependencies."
